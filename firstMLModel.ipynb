# %% [markdown]
# <a href="https://colab.research.google.com/github/yashghogre/First-ML-Model/blob/main/firstMLModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('melon.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state = 1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
print(X_test," : ",y_test)
# Out:
# [[ 3]
#  [10]]  :  [140 390]

# %%
print(X_test," : ",y_pred)
# Out:
# [[ 3]
#  [10]]  :  [136.08108108 420.4954955 ]

# %%
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Weight v/s Price of Watermelon (Train)')
plt.xlabel('Weight(kg)')
plt.ylabel('Price')
plt.show()

# %%
plt.scatter(X_test, y_test, color='red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Weight v/s Price of Watermelon (Test)')
plt.xlabel('Weight(kg)')
plt.ylabel('Price')
plt.show()
